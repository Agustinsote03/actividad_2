# %%
#En esta celda están las importaciones necesarias

import os
import sys
import pathlib

#Se muestra el directorio actual y la ruta raíz del proyecto

directorio_actual = os.getcwd()
print(f"Directorio actual: ", directorio_actual)
print()

ruta_raiz = os.path.abspath(os.path.join(directorio_actual, '..'))
print(f"Ruta raíz: ", ruta_raiz)
print()

#Se añade la ruta raíz al sys.path para poder importar módulos desde esa ubicación

sys.path.append(ruta_raiz)
import funciones as fn
print("Se importó correctamente el módulo funciones")
# Out:
# Directorio actual:  c:\Users\Agustin\Desktop\Python2026\actividad_2\notebooks
#
# Ruta raíz:  c:\Users\Agustin\Desktop\Python2026\actividad_2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 20
#      16
#      17 #Se añade la ruta raíz al sys.path para poder importar módulos desde esa ubicación
#      18
#      19 sys.path.append(ruta_raiz)
# ---> 20 import funciones as fn
#      21 print("Se importó correctamente el módulo funciones")
#      22
#      23
#
# ModuleNotFoundError: No module named 'funciones'

# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way
to do it.
Although that way may not be obvious at first unless you're
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good
idea.
Namespaces are one honking great idea -- let's do more of
those!"""

print(text)
fn.funcion1()
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way
# to do it.
# Although that way may not be obvious at first unless you're
# Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good
# idea.
# Namespaces are one honking great idea -- let's do more of
# those!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 26
#      22 Namespaces are one honking great idea -- let's do more of
#      23 those!"""
#      24
#      25 print(text)
# ---> 26 fn.funcion1
#
# AttributeError: module 'funciones' has no attribute 'funcion1'
